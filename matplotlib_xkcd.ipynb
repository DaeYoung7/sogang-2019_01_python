# %%
# %matplotlib nbagg

import matplotlib.pylab as plt

import numpy as np

 

X=np.linspace(-np.pi,np.pi,256)

C=np.cos(X)

with plt.xkcd():

    plt.title("XKCD style plot!!!")

    plt.plot(X,C)

    plt.plot(2*np.pi/3,np.cos(2*np.pi/3),c="r",marker="o",ms=3)

    plt.annotate(r'$0.5 HERE!$',xy=(2*np.pi/3,np.cos(2*np.pi/3)),xycoords="data",

                 xytext=(-100,-50),textcoords="offset points", 

                 arrowprops=dict(arrowstyle="->",linewidth=1,color="k"))

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.6946844302469">

# %%
# %matplotlib nbagg
import matplotlib.pylab as plt
import numpy as np
with plt.xkcd():
    plt.ylabel("my overall health")
    plt.xlabel('time\n"stove Ownership"from xkcd by Randall Monroe')
    plt.ylim(0,3.5)
    plt.xticks([])
    plt.yticks([])
    plt.plot([2,2,2,2,2,1,0])
    plt.annotate('THE DAY I REALIZED\nI COULD COOK BACON\nWHENEVER I WATED',
                 xy=(4,2),xycoords="data",xytext=(-180,-50),textcoords="offset points",
                 arrowprops=dict(arrowstyle="->",linewidth=1,color="k"))
# Out:
# <img src="data:image/png;base64,..." width="639.6946844302469">
